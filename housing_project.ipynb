# %% [markdown]
# <h1 style="color:red">Machine Learning : Linear Regression VS One Neuron</h1>

# %% [markdown]
# <p>Les bibliothèques suivantes sont à utiliser</p>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split #split data ino training data and test data 
import pandas as pnd

# %% [markdown]
# <p style="color:Tomato;">Objectif est de prévoir le  prix des maisons en utilisant deux techniques:<br></p>
#    <h5 style="color:DodgerBlue;">Linear regresison</h5>
#    <h5 style="color:DodgerBlue;">One neuron for regression</h5>

# %%
import pandas as pnd #dataframe
data_frame=pnd.read_csv("Housing.csv")
data_frame.head()
#les trois premières colonnes: features
#la dernière colonne target
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# <h2 style="color:DodgerBlue;">I. Linear Regression Model: (Housing price prediction)</h2>

# %% [markdown]
# <h1 style="color:red">Questions</h1>

# %% [markdown]
# <h3 style="color:Tomato;">Dataset</h3>
# <p>
#     <span  style="color:DodgerBlue;">préparer les données de manières à prendre en compte les précisions suivantes: </span>
# </p>
# <p>
#     <span style="color:Tomato;"><b> 1) features - target:</b></span><br>
#     <span  style="color:DodgerBlue;">les features sont: area, bderooms,bathrooms<br>
#     Target: price
#         <br>
#         écrire le code python pour construire le nouveau dataset de manière à conserver juste ces colonnes
#     </span>
# </p>
#
# <p>
#     <span style="color:Tomato;"><b> 2) standardisation de données:</b></span><br>
#     <span  style="color:DodgerBlue;">pourquoi nous avons besoin de standardiser les données? <br>
#     <br>écrire le code python vous permettant d'appliquer la standardisation
#     </span>
# </p>
#
# <p>
#     <span style="color:Tomato;"><b> 3) split data:</b></span><br>
#     <span  style="color:DodgerBlue;">
#     <br>diviser le dataset en training dataset et en test dataset
#     </span>
# </p>
#
# <h3 style="color:Tomato;">Model</h3>
# <p>
#     <span style="color:Tomato;"><b> 4) la fonction train:</b></span><br>
#     <span  style="color:DodgerBlue;">écrire le code python de la fonction train <br>
#     train(X,y) qui permet de retourner le bias et les poids nécessaires<br>
#           </span>
# </p>
#
# <p>
#     <span style="color:Tomato;"><b> 5) analyse de mse en fonctions des itérations:</b>
#     </span>
#     <br>
#     <span  style="color:DodgerBlue;">ajouter le code dans la fonction train qui permet mémoriser les valeurs de mse relatives aux itérations </span>
#     <br>
# <span  style="color:DodgerBlue;">tracer le graphe qui montre l'évolution de mse en fonctions des  itérations
#     <br>
#   </span>
# </p>
#
# <p>
#     <span style="color:Tomato;"><b> 6) réglage:</b></span><br>
#     <span  style="color:DodgerBlue;">quelles sont les valeurs de epochs et learning_rate qui assurent un modèle de performance accepatbale <br>
#         <span  style="color:DodgerBlue;">Tester la fonction train<br></span>
# </span>
# </p>
#
# <p>
#     <span style="color:Tomato;"><b> 7) prediction:</b></span><br>
#     <span  style="color:DodgerBlue;">écrire le code source de la fonction predict <br>
#         <span  style="color:DodgerBlue;">Tester la fonction <br></span>
#
# </span>
# </p>
#
# <p>
#     <span style="color:Tomato;"><b> 8) évaluation:</b></span><br>
#     <span  style="color:DodgerBlue;">écrire le code source de la fonction mean_squared_error qui permet d'évaluer la performance du modèle <br>
#         <span  style="color:DodgerBlue;">Tester la fonction <br></span>
# </span>
# </p>
